# %%
import face_alignment
import dlib
import cv2
from skimage import io
from skimage import img_as_ubyte
import skimage
import imutils 

import matplotlib.pyplot as plt


fa = face_alignment.FaceAlignment(face_alignment.LandmarksType._2D, device='cpu', face_detector='blazeface')
# fa = face_alignment.FaceAlignment(face_alignment.LandmarksType._2D, device='cpu', face_detector='sfd')
imagefile = 'Dataset/Train/img/1.png'
image = cv2.imread(imagefile)

print(image.shape)

det = fa.get_landmarks_from_image(image, return_bboxes=True) 
print(det)

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Create figure and axes
fig, ax = plt.subplots()
ax.imshow(image)

marks = det[0]
rects = det[2]

for detection in marks:
    plt.scatter(detection[:,0], detection[:,1], 2)

plt.show()
# Out:
# (1080, 800, 3)
# ([array([[251., 413.],
#        [256., 455.],
#        [261., 490.],
#        [271., 526.],
#        [282., 568.],
#        [302., 598.],
#        [328., 624.],
#        [354., 645.],
#        [400., 660.],
#        [446., 645.],
#        [477., 624.],
#        [498., 603.],
#        [523., 573.],
#        [534., 532.],
#        [544., 496.],
#        [554., 455.],
#        [554., 419.],
#        [277., 377.],
#        [297., 372.],
#        [318., 367.],
#        [343., 372.],
#        [359., 383.],
#        [446., 377.],
#        [467., 372.],
#        [487., 367.],
#        [513., 372.],
#        [528., 383.],
#        [405., 419.],
#        [405., 444.],
#        [405., 470.],
#        [405., 490.],
#        [379., 506.],
#        [390., 511.],
#        [400., 511.],
#        [415., 511.],
#        [426., 506.],
#        [302., 413.],
#        [318., 408.],
#        [338., 408.],
#        [359., 419.],
#        [338., 424.],
#        [318., 424.],
#        [446., 419.],
#        [467., 408.],
#        [487., 408.],
#        [503., 419.],
#        [487., 424.],
#        [467., 424.],
#        [354., 562.],
#        [369., 552.],
#        [395., 547.],
#        [405., 547.],
#        [415., 547.],
#        [436., 552.],
#        [451., 562.],
#        [436., 573.],
#        [420., 578.],
#        [405., 578.],
#        [385., 578.],
#        [374., 573.],
#        [354., 557.],
#        [390., 557.],
#        [405., 557.],
#        [415., 557.],
#        [451., 557.],
#        [415., 557.],
#        [405., 562.],
#        [390., 557.]], dtype=float32)], None, array([[242.71662903, 335.76161194, 563.28411865, 656.32922363,
#           0.93511587]]))
